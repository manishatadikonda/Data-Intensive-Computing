# %%
install.packages("twitteR", repos="http://cran.us.r-project.org/")
# Out:
# Installing package into 'C:/Users/Akash Yeleswarapu/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# package 'twitteR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Akash Yeleswarapu\AppData\Local\Temp\RtmpMd0MnV\downloaded_packages

# %%
library(twitteR)

# %%
setup_twitter_oauth("6VOXGcI9RcZu6TgkZR8z7icLI", "L2txGKiWqSctX6H7zw5BjwRQumXs3NB1rKTHXsE6vbT9ok34V3", "1155945294-a4Ds2mz3a3JgA3Sh232GenlpU6Fd0ZJxWwuAIkF", "WVQBUB0HESaNelGyl2ymELlkUKHpOM0WnSLfjHki2s3ts")
# Out:
# [1] "Using direct authentication"

# %%
tweets <- searchTwitter('iphone', n=50)
# Out:
# [1] "Rate limited .... blocking for a minute and retrying up to 119 times ..."
# [1] "Rate limited .... blocking for a minute and retrying up to 118 times ..."
# [1] "Rate limited .... blocking for a minute and retrying up to 117 times ..."
# [1] "Rate limited .... blocking for a minute and retrying up to 116 times ..."
# [1] "Rate limited .... blocking for a minute and retrying up to 115 times ..."
# [1] "Rate limited .... blocking for a minute and retrying up to 114 times ..."

# %%
head(tweets)
# Out:
# [[1]]
# [1] "___rooock: iPhone<U+306E><U+30A2><U+30E9><U+30FC><U+30E0><U+6A5F><U+80FD><U+3063><U+3066><U+30B5><U+30A4><U+30EC><U+30F3><U+30C8><U+306B><U+3057><U+3066><U+3066><U+3082><U+8A2D><U+5B9A><U+3057><U+3066><U+305F><U+3089><U+97F3><U+306A><U+308B><U+FF1F>"
#
# [[2]]
# [1] "mediatelecomtec: El iPhone 8 tendrá una pantalla sin marcos, pero no aumentará apenas su tamaño https://t.co/XVkQZXTZFu https://t.co/M5wzXGPiSy"
#
# [[3]]
# ...

# %%
sample <- getUser('eveehunt')

# %%
sample$getDescription()
# Out:
# [1] "They asked her what she saw in him and she just smiled because she doesn't want others to fall for him like she did."

# %%
sample$getFollowersCount()
# Out:
# [1] 14297

# %%
sample$getFriends(n=5)
# Out:
# $`496446047`
# [1] "smohloli"
#
# $`2811015129`
# [1] "osamaelsyed36"
#
# $`1409549893`
# [1] "Anointmatizani"
#
# $`2179892339`
# [1] "_vip_z"
#
# $`1623039943`
# [1] "albandry_q79"

# %%
sample$getFavorites(n=5)
# Out:
# [[1]]
# [1] "eveehunt: Into Thin Air - Jon Krakauer | http://t.co/dzhY4Cpag6 | Travel &amp; Adventure #audiobook #Travel #Adventure"
#
# [[2]]
# [1] "eveehunt: One Man's Wilderness: An Alaskan Odyssey (Unabridged) - Sam Keith, Richard  | http://t.co/BXCfg1N9LS | Travel &amp; Adventure #audiobook #Trave"
#
# [[3]]
# [1] "eveehunt: How to Create a Mind: The Secret of Human Thought Revealed (Unabridged) - R | http://t.co/C67OaEWTHz | Technology #audiobook #Technology"
#
# [[4]]
# [1] "eveehunt: Walk and Talk Rome (Unabridged) [Unabridged Nonfiction] - Anya Shetterly | http://t.co/3SuQjrwxkq | Travel &amp; Adventure #audiobook #Travel #"
#
# [[5]]
# [1] "eveehunt: Korean Phase 1, Unit 01: Learn to Speak and Understand Korean with Pimsleur | http://t.co/slu4UfogQd | Languages #audiobook #Languages"

# %%
df <- twListToDF(tweets)

# %%
head(df)
# Out:
#   text
# 1 iPhone<U+306E><U+30A2><U+30E9><U+30FC><U+30E0><U+6A5F><U+80FD><U+3063><U+3066><U+30B5><U+30A4><U+30EC><U+30F3><U+30C8><U+306B><U+3057><U+3066><U+3066><U+3082><U+8A2D><U+5B9A><U+3057><U+3066><U+305F><U+3089><U+97F3><U+306A><U+308B><U+FF1F>
# 2 El iPhone 8 tendrá una pantalla sin marcos, pero no aumentará apenas su tamaño https://t.co/XVkQZXTZFu https://t.co/M5wzXGPiSy
# ...

# %%
install.packages("RSQLite", repos="http://cran.us.r-project.org/")
# Out:
# Installing package into 'C:/Users/Akash Yeleswarapu/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# also installing the dependencies 'memoise', 'plogr'
# package 'memoise' successfully unpacked and MD5 sums checked
# package 'plogr' successfully unpacked and MD5 sums checked
# package 'RSQLite' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Akash Yeleswarapu\AppData\Local\Temp\RtmpMd0MnV\downloaded_packages

# %%
library(RSQLite)
data_sql = tempfile()
register_sqlite_backend(data_sql)
store_tweets_db(tweets)
# Out:
# [1] TRUE

# %%
data_sql_get = load_tweets_db()

# %%
head(data_sql_get)
# Out:
# [[1]]
# [1] "___rooock: iPhone<U+306E><U+30A2><U+30E9><U+30FC><U+30E0><U+6A5F><U+80FD><U+3063><U+3066><U+30B5><U+30A4><U+30EC><U+30F3><U+30C8><U+306B><U+3057><U+3066><U+3066><U+3082><U+8A2D><U+5B9A><U+3057><U+3066><U+305F><U+3089><U+97F3><U+306A><U+308B><U+FF1F>"
#
# [[2]]
# [1] "mediatelecomtec: El iPhone 8 tendrá una pantalla sin marcos, pero no aumentará apenas su tamaño https://t.co/XVkQZXTZFu https://t.co/M5wzXGPiSy"
#
# [[3]]
# ...

# %%
user_tweets <- userTimeline('erosunokatamar')
user_tweets[1:5]
# Out:
# [[1]]
# [1] "erosunokatamar: <U+30AA><U+30AB><U+30BA><U+3060><U+3088>~<U+266A><U+629C><U+3051><U+305F><U+3089>RT! #<U+30A8><U+30ED><U+52D5><U+753B> #30<U+79D2><U+52D5><U+753B> https://t.co/vaRAZ1k7o5"
#
# [[2]]
# [1] "erosunokatamar: <U+30AA><U+30AB><U+30BA><U+3060><U+3088>~<U+266A><U+629C><U+3051><U+305F><U+3089>RT!  #<U+30A8><U+30ED><U+52D5><U+753B> #30<U+79D2><U+52D5><U+753B> https://t.co/13NWB1IZZp"
#
# [[3]]
# [1] "erosunokatamar: <U+30AA><U+30AB><U+30BA><U+3060><U+3088>~<U+266A><U+629C><U+3051><U+305F><U+3089>RT! #<U+30A8><U+30ED><U+52D5><U+753B> #30<U+79D2><U+52D5><U+753B> https://t.co/HkJenNkVx5"
#
# [[4]]
# [1] "erosunokatamar: https://t.co/IzpoOGEPVE"
#
# [[5]]
# [1] "erosunokatamar: <U+2764><U+8208><U+596E><U+3057><U+305F><U+3089>RT<U+2764><U+203C> #<U+30A8><U+30ED><U+52D5><U+753B> https://t.co/0DtVIqW0Ek"

# %%
user_tweets_large <- userTimeline('erosunokatamar',  n=100)
length(user_tweets_large)
# Out:
# [1] 99

# %%
trends <- availableTrendLocations()

# %%
head(trends)
# Out:
#   name      country woeid
# 1 Worldwide         1
# 2 Winnipeg  Canada  2972
# 3 Ottawa    Canada  3369
# 4 Quebec    Canada  3444
# 5 Montreal  Canada  3534
# 6 Toronto   Canada  4118

# %%
close_trends <- closestTrendLocations(-22, -65)

# %%
head(close_trends)
# Out:
#   name    country   woeid
# 1 Córdoba Argentina 466861

# %%
trends = getTrends(466861)

# %%
head(trends)
# Out:
#   name            url
# 1 Argentina       http://twitter.com/search?q=Argentina
# 2 Disney          http://twitter.com/search?q=Disney
# 3 Milani          http://twitter.com/search?q=Milani
# 4 #happyhopeday   http://twitter.com/search?q=%23happyhopeday
# 5 Leo Rosenwasser http://twitter.com/search?q=%22Leo+Rosenwasser%22
# 6 Icardi          http://twitter.com/search?q=Icardi
#   query                 woeid
# 1 Argentina             466861
# 2 Disney                466861
# 3 Milani                466861
# 4 %23happyhopeday       466861
# 5 %22Leo+Rosenwasser%22 466861
# 6 Icardi                466861

# %%
new_tweets <- searchTwitter('Unilever', n=300)

# %%
sources <- sapply(new_tweets, function(x) x$getStatusSource())
sources <- gsub("</a>", "", sources)
sources <- strsplit(sources, ">")
sources <- sapply(sources, function(x) ifelse(length(x) > 1, x[2], x[1]))
source_table = table(sources)
pie(source_table[source_table > 10])
# Out:
# plot without title
